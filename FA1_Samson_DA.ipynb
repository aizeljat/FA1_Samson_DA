# %%
import pandas as pd
from matplotlib import pyplot as plt

file_path = "C:\\Users\\User\\OneDrive\\FRESHMAN\\3rd yr - 2nd Sem\\Data Analysis\\cytof_one_experiment.csv"

# Read the CSV file
df = pd.read_csv(file_path)

print(df.head())
# Out:
#       NKp30   KIR3DL1     NKp44   KIR2DL1  GranzymeB     CXCR6     CD161  \
# 0  0.187595  3.615693 -0.560569 -0.293665   2.477893 -0.144701 -0.315287
# 1  1.034852  1.700182 -0.288961 -0.479828   3.261016 -0.033924 -0.411213
# 2  2.999640  6.141142  1.903261  0.482310   4.277562  1.946542 -0.502235
# 3  4.299859 -0.221159  0.242571 -0.483127   3.351808  0.926222  3.877237
# 4 -0.438645 -0.503589 -0.152632  0.750613   3.194145 -0.058936  1.090738
#
#     KIR2DS4     NKp46     NKG2D  ...      CD16      TNFa      ILT2  Perforin  \
# 0  1.944970  4.081832  2.620078  ...  3.995142  0.901435 -0.386028  6.431983
# 1  3.802517  3.733930 -0.483279  ...  4.408231  1.935902  2.983875  6.814827
# 2 -0.320102  4.559463 -0.506909  ...  6.002324 -0.023370 -0.521100  5.099562
# 3 -0.169695  4.483149  1.927229  ...  5.823870 -0.607937 -0.043784  5.841797
# 4 -0.050330  0.837936 -0.458167  ...  4.012250 -0.619891  1.182703  4.888777
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#2
# Plot histogram
column_name = 'NKp30'  

plt.figure(figsize=(10, 5))
sns.histplot(df[column_name], kde=True, color='skyblue')
plt.title(f'Histogram of {column_name}')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

print("Analysis")
print("The histogram NKp30 depicts a histogram with a frequency of 1600 and values up to 8. The histogram has an ascending and descending flow.")


# Plot quantile plot
column_name = 'KIR2DS4'  

plt.figure(figsize=(10, 5))
sns.ecdfplot(df[column_name], marker='o', color='purple')
plt.title(f'Quantile plot of {column_name}')
plt.xlabel('Values')
plt.ylabel('Cumulative Probability')
plt.show()

print("Analysis")
print("The Quantile plot of KIR2DS4 shows an ascending order to 0.4 cumulative probability, which continues to rise until 1.0.")
# Out:
# Analysis
# The histogram NKp30 depicts a histogram with a frequency of 1600 and values up to 8. The histogram has an ascending and descending flow.
# Analysis
# The Quantile plot of KIR2DS4 shows an ascending order to 0.4 cumulative probability, which continues to rise until 1.0.

# %%
#3
column1 = 'GranzymeB'  
column2 = 'Perforin'  

# Create a Q-Q plot to compare the distributions of the two columns
plt.figure(figsize=(8, 6))
stats.probplot(df[column1], dist="norm", plot=plt)
stats.probplot(df[column2], dist="norm", plot=plt)
plt.title(f'Q-Q Plot comparing distributions of {column1} and {column2}')
plt.xlabel('Theoretical quantiles')
plt.ylabel('Ordered Values')
plt.legend([column1, column2])
plt.grid(True)
plt.show()

print("Analysis:")
print("I chose to compare the distributions of GranzymeB and Perforin using a QQ plot. The difference between the two is that GranzymeB begins at low theoretical quantiles and shows much lower ordered values, whereas Perforin shows a straight ascending line that can reach up to ten values.They are still arranged in ascending order.")
# Out:
# Analysis:
# I chose to compare the distributions of GranzymeB and Perforin using a QQ plot. The difference between the two is that GranzymeB begins at low theoretical quantiles and shows much lower ordered values, whereas Perforin shows a straight ascending line that can reach up to ten values.They are still arranged in ascending order.
